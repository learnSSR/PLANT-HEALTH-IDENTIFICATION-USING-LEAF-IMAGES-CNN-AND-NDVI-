# %% [markdown]
# # NDVI and CNN based Plant Health Identification using Leaf Images

# %% [markdown]
# # Visualization of Plant Leaves

# %% [markdown]
# # Importing modules

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Reading RGB values of Images

# %%
img_h_1=cv2.imread(r"sample_data/h1.JPG",1)
img_u_1=cv2.imread(r"sample_data/u1.JPG",1)
img_h_2=cv2.imread(r"sample_data/h2.JPG",1)
img_u_2=cv2.imread(r"sample_data/u2.JPG",1)
img_h_3=cv2.imread(r"sample_data/h3.JPG",1)
img_u_3=cv2.imread(r"sample_data/u3.JPG",1)
img_h_4=cv2.imread(r"sample_data/h4.JPG",1)
img_u_4=cv2.imread(r"sample_data/u4.JPG",1)
img_h_5=cv2.imread(r"sample_data/h5.JPG",1)
img_u_5=cv2.imread(r"sample_data/u5.JPG",1)

# %% [markdown]
# # Converting RGB to HSV

# %%
img_hsv_h_1 = cv2.cvtColor(img_h_1, cv2.COLOR_BGR2HSV)
img_hsv_u_1 = cv2.cvtColor(img_u_1, cv2.COLOR_BGR2HSV)
img_hsv_h_2 = cv2.cvtColor(img_h_2, cv2.COLOR_BGR2HSV)
img_hsv_u_2 = cv2.cvtColor(img_u_2, cv2.COLOR_BGR2HSV)
img_hsv_h_3 = cv2.cvtColor(img_h_3, cv2.COLOR_BGR2HSV)
img_hsv_u_3 = cv2.cvtColor(img_u_3, cv2.COLOR_BGR2HSV)
img_hsv_h_4 = cv2.cvtColor(img_h_4, cv2.COLOR_BGR2HSV)
img_hsv_u_4 = cv2.cvtColor(img_u_4, cv2.COLOR_BGR2HSV)
img_hsv_h_5 = cv2.cvtColor(img_h_5, cv2.COLOR_BGR2HSV)
img_hsv_u_5 = cv2.cvtColor(img_u_5, cv2.COLOR_BGR2HSV)

# %%
img_v_h_1=img_hsv_h_1[:,:,1]
img_v_u_1=img_hsv_u_1[:,:,1]
img_v_h_2=img_hsv_h_2[:,:,1]
img_v_u_2=img_hsv_u_2[:,:,1]
img_v_h_3=img_hsv_h_3[:,:,1]
img_v_u_3=img_hsv_u_3[:,:,1]
img_v_h_4=img_hsv_h_4[:,:,1]
img_v_u_4=img_hsv_u_4[:,:,1]
img_v_h_5=img_hsv_h_5[:,:,1]
img_v_u_5=img_hsv_u_5[:,:,1]

# %% [markdown]
# # Viewing original image

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(img_h_1)
plt.title('Healthy_Leaf')
plt.subplot(1,2,2)
plt.imshow(img_u_1)
plt.title('Unhealthy_Leaf')
# Out:
# Text(0.5,1,'Unhealthy_Leaf')

# %% [markdown]
# # Saturation distribution in background and leaf part

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2,right=5)
plt.imshow(img_v_h_1,cmap='hot')
plt.title('Healthy')


plt.subplot(1,2,2)
plt.imshow(img_v_u_1,cmap='hot')
plt.title('Unhealthy')
# Out:
# Text(0.5,1,'Unhealthy')

# %% [markdown]
# # Obtaining Saturation distribution among some scan lines.

# %%
dfs_h = pd.DataFrame(img_v_h_1[10])
dfs_h[1] = pd.DataFrame(img_v_h_1[75])
dfs_h[2] = pd.DataFrame(img_v_h_1[125])
dfs_h.columns = ["Background", "Background and Leaf_1", "Background and Leaf_2"]
dfs_u = pd.DataFrame(img_v_u_1[5])
dfs_u[1] = pd.DataFrame(img_v_u_1[101])
dfs_u[2] = pd.DataFrame(img_v_u_1[125])
dfs_u.columns = ["Background", "Background and Leaf_1", "Background and Leaf_2"]
fig, (ax1, ax2) = plt.subplots(1, 2)
dfs_h.plot(ax=ax1, legend=False,figsize=(16,5))#figsize=(10,4)
ax1.set_title("Sample_Healthy_Leaf")
dfs_u.plot(ax=ax2, legend=False,figsize=(16,5))#,figsize=(10,4)
ax2.set_title("Sample_Unhealthy_Leaf")
# Out:
# Text(0.5,1,'Sample_Unhealthy_Leaf')

# %% [markdown]
# # Subtracting background.

# %%
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_h_1[x][y][1] < 40:
            img_h_1[x][y][0]=0
            img_h_1[x][y][1]=0
            img_h_1[x][y][2]=0
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_u_1[x][y][1] < 40:
            img_u_1[x][y][0]=0
            img_u_1[x][y][1]=0
            img_u_1[x][y][2]=0


for x in range(0,256):
    for y in range(0,256):
        if img_hsv_h_2[x][y][1] < 40:
            img_h_2[x][y][0]=0
            img_h_2[x][y][1]=0
            img_h_2[x][y][2]=0
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_u_2[x][y][1] < 40:
            img_u_2[x][y][0]=0
            img_u_2[x][y][1]=0
            img_u_2[x][y][2]=0


for x in range(0,256):
    for y in range(0,256):
        if img_hsv_h_3[x][y][1] < 40:
            img_h_3[x][y][0]=0
            img_h_3[x][y][1]=0
            img_h_3[x][y][2]=0
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_u_3[x][y][1] < 40:
            img_u_3[x][y][0]=0
            img_u_3[x][y][1]=0
            img_u_3[x][y][2]=0


for x in range(0,256):
    for y in range(0,256):
        if img_hsv_h_4[x][y][1] < 40:
            img_h_4[x][y][0]=0
            img_h_4[x][y][1]=0
            img_h_4[x][y][2]=0
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_u_4[x][y][1] < 40:
            img_u_4[x][y][0]=0
            img_u_4[x][y][1]=0
            img_u_4[x][y][2]=0

            
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_h_5[x][y][1] < 40:
            img_h_5[x][y][0]=0
            img_h_5[x][y][1]=0
            img_h_5[x][y][2]=0
for x in range(0,256):
    for y in range(0,256):
        if img_hsv_u_5[x][y][1] < 40:
            img_u_5[x][y][0]=0
            img_u_5[x][y][1]=0
            img_u_5[x][y][2]=0

# %% [markdown]
# # Backgroung Subtracted Image.

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(img_h_1)
plt.title('Background_Separated_Healthy_Leaf')


plt.subplot(1,2,2)
plt.imshow(img_u_1)
plt.title('Background_Separated_Unhealthy_Leaf')
# Out:
# Text(0.5,1,'Background_Separated_Unhealthy_Leaf')

# %% [markdown]
# # Obtaining NDVI Values.

# %%
l_h_1=list()
l_u_1=list()
l_h_2=list()
l_u_2=list()
l_h_3=list()
l_u_3=list()
l_h_4=list()
l_u_4=list()
l_h_5=list()
l_u_5=list()

# %%
ndvi_array_h=np.zeros(shape=(256,256))
ndvi_array_u=np.zeros(shape=(256,256))

# %%
for x in range(0,256):
    for y in range(0,256):
        if img_h_1[x][y][0] != 0 and img_h_1[x][y][1] != 0 and img_h_1[x][y][2] != 0:
            nir_h_1 = ((1.8474519*img_h_1[x][y][2])-(0.1936929*img_h_1[x][y][1])+(0.12401134*img_h_1[x][y][0]))
            ndvi_array_h[x][y] = a = ((nir_h_1 - img_h_1[x][y][2]) / (nir_h_1 + img_h_1[x][y][2]))
            l_h_1.append(a)
        else:
            ndvi_array_h[x][y] = 0
for x in range(0,256):
    for y in range(0,256):
        if img_u_1[x][y][0] != 0 and img_u_1[x][y][1] != 0 and img_u_1[x][y][2] != 0:
            nir_u_1 = ((1.8474519*img_u_1[x][y][2])-(0.1936929*img_u_1[x][y][1])+(0.12401134*img_u_1[x][y][0]))
            ndvi_array_u[x][y] = a = ((nir_u_1 - img_u_1[x][y][2]) / (nir_u_1 + img_u_1[x][y][2]))
            l_u_1.append(a)
        else:
            ndvi_array_u[x][y] = 0


for x in range(0,256):
    for y in range(0,256):
        if img_h_2[x][y][0] != 0 and img_h_2[x][y][1] != 0 and img_h_2[x][y][2] != 0:
            nir_h_2 = ((1.8474519*img_h_2[x][y][2])-(0.1936929*img_h_2[x][y][1])+(0.12401134*img_h_2[x][y][0]))
            a = ((nir_h_2 - img_h_2[x][y][2]) / (nir_h_2 + img_h_2[x][y][2]))
            l_h_2.append(a)
for x in range(0,256):
    for y in range(0,256):
        if img_u_2[x][y][0] != 0 and img_u_2[x][y][1] != 0 and img_u_2[x][y][2] != 0:
            nir_u_2 = ((1.8474519*img_u_2[x][y][2])-(0.1936929*img_u_2[x][y][1])+(0.12401134*img_u_2[x][y][0]))
            a = ((nir_u_2 - img_u_2[x][y][2]) / (nir_u_2 + img_u_2[x][y][2]))
            l_u_2.append(a)


for x in range(0,256):
    for y in range(0,256):
        if img_h_3[x][y][0] != 0 and img_h_3[x][y][1] != 0 and img_h_3[x][y][2] != 0:
            nir_h_3 = ((1.8474519*img_h_3[x][y][2])-(0.1936929*img_h_3[x][y][1])+(0.12401134*img_h_3[x][y][0]))
            a = ((nir_h_3 - img_h_3[x][y][2]) / (nir_h_3 + img_h_3[x][y][2]))
            l_h_3.append(a)
for x in range(0,256):
    for y in range(0,256):
        if img_u_3[x][y][0] != 0 and img_u_3[x][y][1] != 0 and img_u_3[x][y][2] != 0:
            nir_u_3 = ((1.8474519*img_u_3[x][y][2])-(0.1936929*img_u_3[x][y][1])+(0.12401134*img_u_3[x][y][0]))
            a = ((nir_u_3 - img_u_3[x][y][2]) / (nir_u_3 + img_u_3[x][y][2]))
            l_u_3.append(a)


for x in range(0,256):
    for y in range(0,256):
        if img_h_4[x][y][0] != 0 and img_h_4[x][y][1] != 0 and img_h_4[x][y][2] != 0:
            nir_h_4 = ((1.8474519*img_h_4[x][y][2])-(0.1936929*img_h_4[x][y][1])+(0.12401134*img_h_4[x][y][0]))
            a = ((nir_h_4 - img_h_4[x][y][2]) / (nir_h_4 + img_h_4[x][y][2]))
            l_h_4.append(a)
for x in range(0,256):
    for y in range(0,256):
        if img_u_4[x][y][0] != 0 and img_u_4[x][y][1] != 0 and img_u_4[x][y][2] != 0:
            nir_u_4 = ((1.8474519*img_u_4[x][y][2])-(0.1936929*img_u_4[x][y][1])+(0.12401134*img_u_4[x][y][0]))
            a = ((nir_u_4 - img_u_4[x][y][2]) / (nir_u_4 + img_u_4[x][y][2]))
            l_u_4.append(a)


for x in range(0,256):
    for y in range(0,256):
        if img_h_5[x][y][0] != 0 and img_h_5[x][y][1] != 0 and img_h_5[x][y][2] != 0:
            nir_h_5 = ((1.8474519*img_h_5[x][y][2])-(0.1936929*img_h_5[x][y][1])+(0.12401134*img_h_5[x][y][0]))
            a = ((nir_h_5 - img_h_5[x][y][2]) / (nir_h_5 + img_h_5[x][y][2]))
            l_h_5.append(a)
for x in range(0,256):
    for y in range(0,256):
        if img_u_5[x][y][0] != 0 and img_u_5[x][y][1] != 0 and img_u_5[x][y][2] != 0:
            nir_u_5 = ((1.8474519*img_u_5[x][y][2])-(0.1936929*img_u_5[x][y][1])+(0.12401134*img_u_5[x][y][0]))
            a = ((nir_u_5 - img_u_5[x][y][2]) / (nir_u_5 + img_u_5[x][y][2]))
            l_u_5.append(a)

# %%
dfn=pd.DataFrame(l_h_1)
dfn1=pd.DataFrame(l_u_1)
dfn2=pd.DataFrame(l_h_2)
dfn3=pd.DataFrame(l_u_2)
dfn4=pd.DataFrame(l_h_3)
dfn5=pd.DataFrame(l_u_3)
dfn6=pd.DataFrame(l_h_4)
dfn7=pd.DataFrame(l_u_4)
dfn8=pd.DataFrame(l_h_5)
dfn9=pd.DataFrame(l_u_5)

# %% [markdown]
# # NDVI distribution in Healthy and Unhealthy images.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
dfn.plot(ax=ax1, legend=False,figsize=(16,5))#figsize=(10,4)
ax1.set_title("Healthy")
dfn1.plot(ax=ax2, legend=False,figsize=(16,5))#,figsize=(10,4)
ax2.set_title("Unhealthy")
'''fig, (ax1, ax2) = plt.subplots(1, 2)
dfn4.plot(ax=ax1, legend=False,figsize=(16,5))
ax1.set_title("Healthy_2")
dfn5.plot(ax=ax2, legend=False,figsize=(16,5))
ax2.set_title("Unhealthy_2")
fig, (ax1, ax2) = plt.subplots(1, 2)
dfn6.plot(ax=ax1, legend=False,figsize=(16,5))
ax1.set_title("Healthy_3")
dfn7.plot(ax=ax2, legend=False,figsize=(16,5))
ax2.set_title("Unhealthy_3")'''
# Out:
# 'fig, (ax1, ax2) = plt.subplots(1, 2)\ndfn4.plot(ax=ax1, legend=False,figsize=(16,5))\nax1.set_title("Healthy_2")\ndfn5.plot(ax=ax2, legend=False,figsize=(16,5))\nax2.set_title("Unhealthy_2")\nfig, (ax1, ax2) = plt.subplots(1, 2)\ndfn6.plot(ax=ax1, legend=False,figsize=(16,5))\nax1.set_title("Healthy_3")\ndfn7.plot(ax=ax2, legend=False,figsize=(16,5))\nax2.set_title("Unhealthy_3")'

# %% [markdown]
# # Determining range of NDVI for Different Healthy and Unhealthy Leaves

# %%
#Healthy 1
l_h_1_n = sorted(l_h_1)
min_h_1 = l_h_1_n[0]
max_h_1 = l_h_1_n[-1]
avg_h_1 = sum(l_h_1_n)/len(l_h_1_n)
#Unhealthy 1
l_u_1_n = sorted(l_u_1)
min_u_1 = l_u_1_n[0]
max_u_1 = l_u_1_n[-1]
avg_u_1 = sum(l_u_1_n)/len(l_u_1_n)

#Healthy 2
l_h_2_n = sorted(l_h_2)
min_h_2 = l_h_2_n[0]
max_h_2 = l_h_2_n[-1]
avg_h_2 = sum(l_h_2_n)/len(l_h_2_n)
#Unhealthy 2
l_u_2_n = sorted(l_u_2)
min_u_2 = l_u_2_n[0]
max_u_2 = l_u_2_n[-1]
avg_u_2 = sum(l_u_2_n)/len(l_u_2_n)

#Healthy 3
l_h_3_n = sorted(l_h_3)
min_h_3 = l_h_3_n[0]
max_h_3 = l_h_3_n[-1]
avg_h_3 = sum(l_h_3_n)/len(l_h_3_n)
#Unhealthy 3
l_u_3_n = sorted(l_u_3)
min_u_3 = l_u_3_n[0]
max_u_3 = l_u_3_n[-1]
avg_u_3 = sum(l_u_3_n)/len(l_u_3_n)

#Healthy 4
l_h_4_n = sorted(l_h_4)
min_h_4 = l_h_4_n[0]
max_h_4 = l_h_4_n[-1]
avg_h_4 = sum(l_h_4_n)/len(l_h_4_n)
#Unhealthy 4
l_u_4_n = sorted(l_u_4)
min_u_4 = l_u_4_n[0]
max_u_4 = l_u_4_n[-1]
avg_u_4 = sum(l_u_4_n)/len(l_u_4_n)

#Healthy 5
l_h_5_n = sorted(l_h_5)
min_h_5 = l_h_5_n[0]
max_h_5 = l_h_5_n[-1]
avg_h_5 = sum(l_h_5_n)/len(l_h_5_n)
#Unhealthy 5
l_u_5_n = sorted(l_u_5)
min_u_5 = l_u_5_n[0]
max_u_5 = l_u_5_n[-1]
avg_u_5 = sum(l_u_5_n)/len(l_u_5_n)

# %%
w, h = 6, 6;
ndvi_list = [[0 for x in range(w)] for y in range(h)]
ndvi_list[0][0] = min_h_1
ndvi_list[0][1] = max_h_1
ndvi_list[0][2] = avg_h_1
ndvi_list[0][3] = min_u_1
ndvi_list[0][4] = max_u_1
ndvi_list[0][5] = avg_u_1

ndvi_list[1][0] = min_h_2
ndvi_list[1][1] = max_h_2
ndvi_list[1][2] = avg_h_2
ndvi_list[1][3] = min_u_2
ndvi_list[1][4] = max_u_2
ndvi_list[1][5] = avg_u_2

ndvi_list[2][0] = min_h_3
ndvi_list[2][1] = max_h_3
ndvi_list[2][2] = avg_h_3
ndvi_list[2][3] = min_u_3
ndvi_list[2][4] = max_u_3
ndvi_list[2][5] = avg_u_3

ndvi_list[3][0] = min_h_4
ndvi_list[3][1] = max_h_4
ndvi_list[3][2] = avg_h_4
ndvi_list[3][3] = min_u_4
ndvi_list[3][4] = max_u_4
ndvi_list[3][5] = avg_u_4

ndvi_list[4][0] = min_h_5
ndvi_list[4][1] = max_h_5
ndvi_list[4][2] = avg_h_5
ndvi_list[4][3] = min_u_5
ndvi_list[4][4] = max_u_5
ndvi_list[4][5] = avg_u_5

# %%
a=0.0
b=0.0
c=0.0
d=0.0
e=0.0
f=0.0
for x in range(5):
    a = a + ndvi_list[x][0]
    b = b + ndvi_list[x][1]
    c = c + ndvi_list[x][2]
    d = d + ndvi_list[x][3]
    e = e + ndvi_list[x][4]
    f = f + ndvi_list[x][5]
ndvi_list[5][0] = a/5
ndvi_list[5][1] = b/5
ndvi_list[5][2] = c/5
ndvi_list[5][3] = d/5
ndvi_list[5][4] = e/5
ndvi_list[5][5] = f/5

# %% [markdown]
# # Obtaining min and avg NDVI Values for 5 healthy and 5 unhealthy leaves.

# %%
w, h = 3, 10;
avg_list = [[0 for x in range(w)] for y in range(h)]
avg_list[0][0] = "Healthy_1"
avg_list[0][1] = avg_min_h_1 = sum(l_h_1_n[0:5000])/5000
avg_list[0][2] = avg_max_h_1 = sum(l_h_1_n[5000:])/(len(l_h_1)-5000)
avg_list[5][0] = "Unhealthy_1"
avg_list[5][1] = avg_min_u_1 = sum(l_u_1_n[0:5000])/5000
avg_list[5][2] = avg_max_u_1 = sum(l_u_1_n[5000:])/(len(l_u_1)-5000)
avg_list[1][0] = "Healthy_2"
avg_list[1][1] = avg_min_h_2 = sum(l_h_2_n[0:5000])/5000
avg_list[1][2] = avg_max_h_2 = sum(l_h_2_n[5000:])/(len(l_h_2)-5000)
avg_list[6][0] = "Unhealthy_2"
avg_list[6][1] = avg_min_u_2 = sum(l_u_2_n[0:5000])/5000
avg_list[6][2] = avg_max_u_2 = sum(l_u_2_n[5000:])/(len(l_u_2)-5000)
avg_list[2][0] = "Healthy_3"
avg_list[2][1] = avg_min_h_3 = sum(l_h_3_n[0:5000])/5000
avg_list[2][2] = avg_max_h_3 = sum(l_h_3_n[5000:])/(len(l_h_3)-5000)
avg_list[7][0] = "Unhealthy_3"
avg_list[7][1] = avg_min_u_3 = sum(l_u_3_n[0:5000])/5000
avg_list[7][2] = avg_max_u_3 = sum(l_u_3_n[5000:])/(len(l_u_3)-5000)
avg_list[3][0] = "Healthy_4"
avg_list[3][1] = avg_min_h_4 = sum(l_h_4_n[0:5000])/5000
avg_list[3][2] = avg_max_h_4 = sum(l_h_4_n[5000:])/(len(l_h_4)-5000)
avg_list[8][0] = "Unhealthy_4"
avg_list[8][1] = avg_min_u_4 = sum(l_u_4_n[0:5000])/5000
avg_list[8][2] = avg_max_u_4 = sum(l_u_4_n[5000:])/(len(l_u_4)-5000)
avg_list[4][0] = "Healthy_5"
avg_list[4][1] = avg_min_h_5 = sum(l_h_5_n[0:5000])/5000
avg_list[4][2] = avg_max_h_5 = sum(l_h_5_n[5000:])/(len(l_h_5)-5000)
avg_list[9][0] = "Unhealthy_5"
avg_list[9][1] = avg_min_u_5 = sum(l_u_5_n[0:5000])/5000
avg_list[9][2] = avg_max_u_5 = sum(l_u_5_n[5000:])/(len(l_u_5)-5000)

# %%
df1 = pd.DataFrame(avg_list)
df1.columns = ["Type", "Avg_Min_NDVI", "Avg_NDVI"]
df1
# Out:
#           Type  Avg_Min_NDVI  Avg_NDVI
# 0    Healthy_1      0.253036  0.262896
# 1    Healthy_2      0.254999  0.263378
# 2    Healthy_3      0.241115  0.256256
# 3    Healthy_4      0.249941  0.259243
# 4    Healthy_5      0.241888  0.258203
# 5  Unhealthy_1      0.229423  0.260644
# 6  Unhealthy_2      0.191904  0.262344
# 7  Unhealthy_3      0.201019  0.258303
# 8  Unhealthy_4      0.212066  0.267491
# 9  Unhealthy_5      0.233041  0.266869

# %%
df2 = df1.loc[[0,1,2,3,4]]
df2
# Out:
#         Type  Avg_Min_NDVI  Avg_NDVI
# 0  Healthy_1      0.253036  0.262896
# 1  Healthy_2      0.254999  0.263378
# 2  Healthy_3      0.241115  0.256256
# 3  Healthy_4      0.249941  0.259243
# 4  Healthy_5      0.241888  0.258203

# %%
df3 = df1.loc[[5,6,7,8,9]]
df3 = df3.reset_index()
df3
# Out:
#    index         Type  Avg_Min_NDVI  Avg_NDVI
# 0      5  Unhealthy_1      0.229423  0.260644
# 1      6  Unhealthy_2      0.191904  0.262344
# 2      7  Unhealthy_3      0.201019  0.258303
# 3      8  Unhealthy_4      0.212066  0.267491
# 4      9  Unhealthy_5      0.233041  0.266869

# %% [markdown]
# # Visualizing the range of NDVI of healthy and unhealthy leaf.

# %%
fig, ax = plt.subplots(1,2, figsize=(16,5), sharey=True)
ax[0].plot(df2['Type'], df2['Avg_Min_NDVI'], label="Avg_Min_NDVI")
ax[0].plot(df2['Type'], df2['Avg_NDVI'], label="Avg_NDVI")
ax[0].set_title("Healthy_NDVI_Range")
ax[0].legend()

#plt.show()

#fig, ax = plt.subplots()
ax[1].plot(df3['Type'], df3['Avg_Min_NDVI'], label="Avg_Min_NDVI")
ax[1].plot(df3['Type'], df3['Avg_NDVI'], label="Avg_NDVI")
ax[1].set_title("Unhealthy_NDVI_Range")
ax[1].legend()

plt.show()

# %% [markdown]
# # Determining relationship between NDVI Values of healthy and unhealthy pixels by plotting healthy NDVI and unhealthy NDVI values.

# %%
#Determining relationship between NDVI Values of healthy and unhealthy pixels and concluding to fix a threshold foe healthy&unhealthy pixels
dtf1=pd.DataFrame(l_h_1_n[0:500])
dtf1[1]=l_u_1_n[0:500]
dtf1.columns = ["Healthy_1", "Unhealthy_1"]
dtf4=pd.DataFrame(l_h_4_n[0:500])
dtf4[1]=l_u_4_n[0:500]
dtf4.columns = ["Healthy_4", "Unhealthy_4"]

fig, ax = plt.subplots(figsize=(16,5))
ax.plot(dtf1.index, dtf1["Healthy_1"], label="Healthy")
ax.plot(dtf1.index, dtf1['Unhealthy_1'], label="Unhealthy")
ax.set_title("Healthy & Unhealthy")
ax.legend()

plt.show()

'''#fig, ax = plt.subplots()
ax[1].plot(dtf4.index, dtf4['Healthy_4'], label="Healthy_2")
ax[1].plot(dtf4.index, dtf4['Unhealthy_4'], label="Unhealthy_2")
ax[1].set_title("Healthy_2 & Unhealthy_2")
ax[1].legend()

plt.show()'''
# Out:
# '#fig, ax = plt.subplots()\nax[1].plot(dtf4.index, dtf4[\'Healthy_4\'], label="Healthy_2")\nax[1].plot(dtf4.index, dtf4[\'Unhealthy_4\'], label="Unhealthy_2")\nax[1].set_title("Healthy_2 & Unhealthy_2")\nax[1].legend()\n\nplt.show()'

# %% [markdown]
# # Plot to obtain threshold for categorizing NDVI Index for healthy and unhealthy pixels.

# %%
fig, ax = plt.subplots(figsize=(16,5))
ax.plot(df2.index, df2['Avg_Min_NDVI'], label="Healthy")
ax.plot(df3.index, df3['Avg_Min_NDVI'], label="Unhealthy")
ax.set_title("Healthy_NDVI_Range")
ax.legend()

plt.show()

# %% [markdown]
# # Visualizing the NDVI Images on different color maps.

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(ndvi_array_h,cmap='binary')
plt.title('Healthy_NDVI_Binary_Image')


plt.subplot(1,2,2)
plt.imshow(ndvi_array_u,cmap='binary')
plt.title('Unhealthy_NDVI_Binary_Image')
# Out:
# Text(0.5,1,'Unhealthy_NDVI_Binary_Image')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(ndvi_array_h,cmap='hot')
plt.title('Healthy_NDVI_Hot_Image')


plt.subplot(1,2,2)
plt.imshow(ndvi_array_u,cmap='hot')
plt.title('Unhealthy_NDVI_Hot_Image')
# Out:
# Text(0.5,1,'Unhealthy_NDVI_Hot_Image')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(ndvi_array_h,cmap='gray')
plt.title('Healthy_NDVI_Monochromatic_Image')


plt.subplot(1,2,2)
plt.imshow(ndvi_array_u,cmap='gray')
plt.title('Unhealthy_NDVI_Monochromatic_Image')
# Out:
# Text(0.5,1,'Unhealthy_NDVI_Monochromatic_Image')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
imgplot = plt.imshow(ndvi_array_h)
plt.colorbar()
plt.title('Healthy_NDVI_Image_with_Colorbar')


plt.subplot(1,2,2)
imgplot = plt.imshow(ndvi_array_u)
plt.colorbar()
plt.title('Unhealthy_NDVI_Image_with_Colorbar')
# Out:
# Text(0.5,1,'Unhealthy_NDVI_Image_with_Colorbar')

# %%
plt.figure()
plt.subplot(1,2,1)
plt.subplots_adjust(left=2, right=5)
plt.imshow(ndvi_array_h, cmap='nipy_spectral')
plt.title('Healthy_NDVI_Image_with_Colorbar')


plt.subplot(1,2,2)
plt.imshow(ndvi_array_u, cmap='nipy_spectral')
plt.title('Unhealthy_NDVI_Image_with_nipy_spectral')
#imgplot = plt.imshow(ndvi_array)
#imgplot.set_cmap('nipy_spectral')
# Out:
# Text(0.5,1,'Unhealthy_NDVI_Image_with_nipy_spectral')

# %%
k_h_1_u = 0
k_h_1_h = 0
k_u_1_u = 0
k_u_1_h = 0
k_h_2_u = 0
k_h_2_h = 0
k_u_2_u = 0
k_u_2_h = 0
k_h_3_u = 0
k_h_3_h = 0
k_u_3_u = 0
k_u_3_h = 0
k_h_4_u = 0
k_h_4_h = 0
k_u_4_u = 0
k_u_4_h = 0
k_h_5_u = 0
k_h_5_h = 0
k_u_5_u = 0
k_u_5_h = 0

k_r_h = list()
k_r_u = list()

for x in range(len(l_h_1)):
    if l_h_1[x] < 0.2463804:
        k_h_1_u=k_h_1_u+1
    else:
        k_h_1_h=k_h_1_h+1
k_r_h.append((k_h_1_u / (k_h_1_u + k_h_1_h)))
for x in range(len(l_u_1)):
    if l_u_1[x] < 0.2463804:
        k_u_1_u=k_u_1_u+1
    else:
        k_u_1_h=k_u_1_h+1
k_r_u.append((k_u_1_u / (k_u_1_u + k_u_1_h)))
    
for x in range(len(l_h_2)):
    if l_h_2[x] < 0.2463804:
        k_h_2_u=k_h_2_u+1
    else:
        k_h_2_h=k_h_2_h+1
k_r_h.append((k_h_2_u / (k_h_2_u + k_h_2_h)))
for x in range(len(l_u_2)):
    if l_u_2[x] < 0.2463804:
        k_u_2_u=k_u_2_u+1
    else:
        k_u_2_h=k_u_2_h+1
k_r_u.append((k_u_2_u / (k_u_2_u + k_u_2_h)))
    
for x in range(len(l_h_3)):
    if l_h_3[x] < 0.2463804:
        k_h_3_u=k_h_3_u+1
    else:
        k_h_3_h=k_h_3_h+1
k_r_h.append((k_h_3_u / (k_h_3_u + k_h_3_h)))
for x in range(len(l_u_3)):
    if l_u_3[x] < 0.2463804:
        k_u_3_u=k_u_3_u+1
    else:
        k_u_3_h=k_u_3_h+1
k_r_u.append((k_u_3_u / (k_u_3_u + k_u_3_h)))
    
for x in range(len(l_h_4)):
    if l_h_4[x] < 0.2463804:
        k_h_4_u=k_h_4_u+1
    else:
        k_h_4_h=k_h_4_h+1
k_r_h.append((k_h_4_u / (k_h_4_u + k_h_4_h)))
for x in range(len(l_u_4)):
    if l_u_4[x] < 0.2463804:
        k_u_4_u=k_u_4_u+1
    else:
        k_u_4_h=k_u_4_h+1
k_r_u.append((k_u_4_u / (k_u_4_u + k_u_4_h)))
    
for x in range(len(l_h_5)):
    if l_h_5[x] < 0.2463804:
        k_h_5_u=k_h_5_u+1
    else:
        k_h_5_h=k_h_5_h+1
k_r_h.append((k_h_5_u / (k_h_5_u + k_h_5_h)))
for x in range(len(l_u_5)):
    if l_u_5[x] < 0.2463804:
        k_u_5_u=k_u_5_u+1
    else:
        k_u_5_h=k_u_5_h+1
k_r_u.append((k_u_5_u / (k_u_5_u + k_u_5_h)))

# %%
k_r_u
# Out:
# [0.28944057446220883,
#  0.2659941677081474,
#  0.4224763695232127,
#  0.34509146181665706,
#  0.19418595402847372]

# %%
k_r_h
# Out:
# [0.014177589071441758,
#  0.006139882541377469,
#  0.1767395489548955,
#  0.018235505366904752,
#  0.14535513974642975]

# %%
dfr=pd.DataFrame(k_r_h)
dfr[1]=k_r_u
dfr
# Out:
#           0         1
# 0  0.014178  0.289441
# 1  0.006140  0.265994
# 2  0.176740  0.422476
# 3  0.018236  0.345091
# 4  0.145355  0.194186

# %%
fig, ax = plt.subplots(figsize=(16,5))
ax.plot(dfr.index, dfr[0], label="Healthy")
ax.plot(dfr.index, dfr[1], label="Unhealthy")
ax.set_title("Ratio of Healthy and Unhealthy pixels in Healthy and Unhealthy Leaves")
ax.legend()

plt.show()
