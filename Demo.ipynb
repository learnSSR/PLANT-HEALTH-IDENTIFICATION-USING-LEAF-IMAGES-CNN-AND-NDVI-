# %%
import utilities as ut

# %%
filepath = "sample_data/u5.JPG"
ut.plot_image(filepath)

# %%
cnn_output = ut.cnn_prediction(filepath, classifier)
ndvi_output = ut.ndvi_prediction(filepath)
result = ut.compare_output(cnn_output,ndvi_output)
print("CNN_Prediction   |  ", cnn_output)
print("NDVI_Prediction  |  ", cnn_output)
print("Final_Prediction |  ", cnn_output)
# Out:
# CNN_Prediction   |   unhealthy
# NDVI_Prediction  |   unhealthy
# Final_Prediction |   unhealthy
